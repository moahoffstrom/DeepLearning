# %% [markdown]
# # DON'T EDIT THIS NOTEBOOK
# ## DOWNLOAD IT AND THEN IMPORT to A NEW ONE

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score 
import os
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Flatten,Dense

# %%
data_dir = '../input/gtsrb-german-traffic-sign'
train_path = '../input/gtsrb-german-traffic-sign/Train'
test_path = '../input/gtsrb-german-traffic-sign/Test'

# %%
IMG_HEIGHT = 32
IMG_WIDTH = 32
NUM_CATEGORIES = len(os.listdir(train_path))

# %%
print(NUM_CATEGORIES)
# Out:
# 43

# %%
classes = { 0:'Speed limit (20km/h)',
 1:'Speed limit (30km/h)',
 2:'Speed limit (50km/h)',
 3:'Speed limit (60km/h)',
 4:'Speed limit (70km/h)',
 5:'Speed limit (80km/h)',
 6:'End of speed limit (80km/h)',
 7:'Speed limit (100km/h)',
 8:'Speed limit (120km/h)',
 9:'No passing',
 10:'No passing veh over 3.5 tons',
 11:'Right-of-way at intersection',
 12:'Priority road',
 13:'Yield',
 14:'Stop',
 15:'No vehicles',
 16:'Veh > 3.5 tons prohibited',
 17:'No entry',
 18:'General caution',
 19:'Dangerous curve left',
 20:'Dangerous curve right',
 21:'Double curve',
 22:'Bumpy road',
 23:'Slippery road',
 24:'Road narrows on the right',
 25:'Road work',
 26:'Traffic signals',
 27:'Pedestrians',
 28:'Children crossing',
 29:'Bicycles crossing',
 30:'Beware of ice/snow',
 31:'Wild animals crossing',
 32:'End speed + passing limits',
 33:'Turn right ahead',
 34:'Turn left ahead',
 35:'Ahead only',
 36:'Go straight or right',
 37:'Go straight or left',
 38:'Keep right',
 39:'Keep left',
 40:'Roundabout mandatory',
 41:'End of no passing',
 42:'End no passing veh > 3.5 tons' }

# %%
image_data = []
image_labels = []

# %%
for i in range(NUM_CATEGORIES):
    path = data_dir + '/Train/' + str(i)
    images = os.listdir(path)
    for img in images:
        image = cv2.imread(path + '/' + img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        image_data.append(np.array(resize_image))
        image_labels.append(i)
# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)
print(image_data.shape, image_labels.shape)
# Out:
# (39209, 32, 32, 3) (39209,)

# %%
shuffle_indexes = np.arange(image_data.shape[0])
np.random.shuffle(shuffle_indexes)
image_data = image_data[shuffle_indexes]
image_labels = image_labels[shuffle_indexes]

# %%
#dividing into validation and training
X_train, X_val, y_train, y_val = train_test_split(image_data, image_labels, test_size=0.3,
random_state=42, shuffle=True)

# %%
X_train = X_train/255
X_val = X_val/255

# %%
print("X_train", X_train.shape)
print("X_valid", X_val.shape)
print("y_train", y_train.shape)
print("y_valid", y_val.shape)
# Out:
# X_train (27446, 32, 32, 3)
# X_valid (11763, 32, 32, 3)
# y_train (27446,)
# y_valid (11763,)

# %%
y_train = keras.utils.to_categorical(y_train,NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)

# %%
print(y_train.shape)
print(y_val.shape)
# Out:
# (27446, 43)
# (11763, 43)

# %%
# Get pretrained model

pretrained_model= tf.keras.applications.VGG19(include_top=False,
                   input_shape=(32,32,3),
                   #pooling='avg',
                   weights='imagenet')

vgg_model_frozen = Sequential()
pretrained_model.trainable = False
#for layer in pretrained_model.layers[:11]:
    #layer.trainable = False
    
        
#for layer in pretrained_model.layers[:-1]: # go through until last layer
    #resnet_model.add(layer)
    

#resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
vgg_model_frozen.add(pretrained_model)
#resnet_model.add(tf.keras.layers.BatchNormalization())
vgg_model_frozen.add(Flatten())

prediction_layer = tf.keras.layers.Dense(43, activation='softmax')
vgg_model_frozen.add(prediction_layer)

#model.compile(optimizer='adam', loss='categorical_crossentropy')
for i, layer in enumerate(pretrained_model.layers):
        print(i, layer.name, "-", layer.trainable)
# Out:
# 0 input_12 - False
# 1 block1_conv1 - False
# 2 block1_conv2 - False
# 3 block1_pool - False
# 4 block2_conv1 - False
# 5 block2_conv2 - False
# 6 block2_pool - False
# 7 block3_conv1 - False
# 8 block3_conv2 - False
# 9 block3_conv3 - False
# 10 block3_conv4 - False
# 11 block3_pool - False
# 12 block4_conv1 - False
# 13 block4_conv2 - False
# 14 block4_conv3 - False
# 15 block4_conv4 - False
# 16 block4_pool - False
# 17 block5_conv1 - False
# 18 block5_conv2 - False
# 19 block5_conv3 - False
# 20 block5_conv4 - False
# 21 block5_pool - False

# %%
lr = 0.0001
epochs = 50
#opt = Adam(learning_rate=lr, decay=lr / (epochs * 0.5))
opt = Adam(learning_rate=lr)

# %%
# Compile model
vgg_model_frozen.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = vgg_model_frozen.fit(X_train, y_train,
batch_size=256, epochs=epochs, validation_data=(X_val,
y_val))
# Out:
# Epoch 1/50
# 108/108 [==============================] - 79s 37ms/step - loss: 3.8616 - accuracy: 0.0318 - val_loss: 3.5696 - val_accuracy: 0.0530
# Epoch 2/50
# 108/108 [==============================] - 4s 34ms/step - loss: 3.3929 - accuracy: 0.1034 - val_loss: 3.2464 - val_accuracy: 0.1364
# Epoch 3/50
# 108/108 [==============================] - 3s 31ms/step - loss: 3.1439 - accuracy: 0.1646 - val_loss: 3.0495 - val_accuracy: 0.1842
# Epoch 4/50
# 108/108 [==============================] - 3s 32ms/step - loss: 2.9765 - accuracy: 0.2064 - val_loss: 2.9071 - val_accuracy: 0.2135
# Epoch 5/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.8497 - accuracy: 0.2342 - val_loss: 2.7956 - val_accuracy: 0.2408
# Epoch 6/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.7482 - accuracy: 0.2580 - val_loss: 2.7044 - val_accuracy: 0.2617
# Epoch 7/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.6634 - accuracy: 0.2792 - val_loss: 2.6270 - val_accuracy: 0.2806
# Epoch 8/50
# 108/108 [==============================] - 4s 33ms/step - loss: 2.5912 - accuracy: 0.2952 - val_loss: 2.5604 - val_accuracy: 0.2972
# Epoch 9/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.5282 - accuracy: 0.3106 - val_loss: 2.5021 - val_accuracy: 0.3145
# Epoch 10/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.4725 - accuracy: 0.3228 - val_loss: 2.4505 - val_accuracy: 0.3230
# Epoch 11/50
# 108/108 [==============================] - 3s 32ms/step - loss: 2.4227 - accuracy: 0.3335 - val_loss: 2.4038 - val_accuracy: 0.3325
# Epoch 12/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.3777 - accuracy: 0.3427 - val_loss: 2.3614 - val_accuracy: 0.3433
# Epoch 13/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.3368 - accuracy: 0.3524 - val_loss: 2.3233 - val_accuracy: 0.3532
# Epoch 14/50
# 108/108 [==============================] - 3s 32ms/step - loss: 2.2994 - accuracy: 0.3627 - val_loss: 2.2878 - val_accuracy: 0.3632
# Epoch 15/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.2648 - accuracy: 0.3720 - val_loss: 2.2553 - val_accuracy: 0.3718
# Epoch 16/50
# 108/108 [==============================] - 3s 30ms/step - loss: 2.2327 - accuracy: 0.3840 - val_loss: 2.2250 - val_accuracy: 0.3799
# Epoch 17/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.2029 - accuracy: 0.3917 - val_loss: 2.1963 - val_accuracy: 0.3920
# Epoch 18/50
# 108/108 [==============================] - 3s 32ms/step - loss: 2.1747 - accuracy: 0.3999 - val_loss: 2.1703 - val_accuracy: 0.4004
# Epoch 19/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.1484 - accuracy: 0.4097 - val_loss: 2.1450 - val_accuracy: 0.4081
# Epoch 20/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.1235 - accuracy: 0.4173 - val_loss: 2.1217 - val_accuracy: 0.4168
# Epoch 21/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.1000 - accuracy: 0.4242 - val_loss: 2.0991 - val_accuracy: 0.4233
# Epoch 22/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.0776 - accuracy: 0.4291 - val_loss: 2.0782 - val_accuracy: 0.4296
# Epoch 23/50
# 108/108 [==============================] - 3s 30ms/step - loss: 2.0563 - accuracy: 0.4363 - val_loss: 2.0581 - val_accuracy: 0.4355
# Epoch 24/50
# 108/108 [==============================] - 3s 31ms/step - loss: 2.0360 - accuracy: 0.4412 - val_loss: 2.0384 - val_accuracy: 0.4422
# Epoch 25/50
# 108/108 [==============================] - 3s 30ms/step - loss: 2.0167 - accuracy: 0.4469 - val_loss: 2.0202 - val_accuracy: 0.4447
# Epoch 26/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.9982 - accuracy: 0.4508 - val_loss: 2.0025 - val_accuracy: 0.4493
# Epoch 27/50
# 108/108 [==============================] - 4s 33ms/step - loss: 1.9803 - accuracy: 0.4589 - val_loss: 1.9856 - val_accuracy: 0.4544
# Epoch 28/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.9632 - accuracy: 0.4618 - val_loss: 1.9695 - val_accuracy: 0.4603
# Epoch 29/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.9468 - accuracy: 0.4667 - val_loss: 1.9538 - val_accuracy: 0.4662
# Epoch 30/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.9311 - accuracy: 0.4710 - val_loss: 1.9387 - val_accuracy: 0.4698
# Epoch 31/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.9158 - accuracy: 0.4757 - val_loss: 1.9246 - val_accuracy: 0.4721
# Epoch 32/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.9011 - accuracy: 0.4751 - val_loss: 1.9104 - val_accuracy: 0.4768
# Epoch 33/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.8869 - accuracy: 0.4812 - val_loss: 1.8972 - val_accuracy: 0.4806
# Epoch 34/50
# 108/108 [==============================] - 3s 32ms/step - loss: 1.8731 - accuracy: 0.4847 - val_loss: 1.8844 - val_accuracy: 0.4824
# Epoch 35/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.8597 - accuracy: 0.4878 - val_loss: 1.8718 - val_accuracy: 0.4848
# Epoch 36/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.8469 - accuracy: 0.4913 - val_loss: 1.8595 - val_accuracy: 0.4853
# Epoch 37/50
# 108/108 [==============================] - 4s 35ms/step - loss: 1.8345 - accuracy: 0.4949 - val_loss: 1.8477 - val_accuracy: 0.4876
# Epoch 38/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.8222 - accuracy: 0.4956 - val_loss: 1.8363 - val_accuracy: 0.4926
# Epoch 39/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.8106 - accuracy: 0.5000 - val_loss: 1.8247 - val_accuracy: 0.4940
# Epoch 40/50
# 108/108 [==============================] - 3s 32ms/step - loss: 1.7990 - accuracy: 0.5012 - val_loss: 1.8144 - val_accuracy: 0.4961
# Epoch 41/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.7879 - accuracy: 0.5045 - val_loss: 1.8034 - val_accuracy: 0.4981
# Epoch 42/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.7770 - accuracy: 0.5070 - val_loss: 1.7935 - val_accuracy: 0.5006
# Epoch 43/50
# 108/108 [==============================] - 3s 32ms/step - loss: 1.7664 - accuracy: 0.5095 - val_loss: 1.7833 - val_accuracy: 0.5028
# Epoch 44/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.7561 - accuracy: 0.5133 - val_loss: 1.7737 - val_accuracy: 0.5073
# Epoch 45/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.7460 - accuracy: 0.5156 - val_loss: 1.7639 - val_accuracy: 0.5085
# Epoch 46/50
# 108/108 [==============================] - 4s 33ms/step - loss: 1.7361 - accuracy: 0.5168 - val_loss: 1.7547 - val_accuracy: 0.5119
# Epoch 47/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.7266 - accuracy: 0.5197 - val_loss: 1.7461 - val_accuracy: 0.5145
# Epoch 48/50
# 108/108 [==============================] - 3s 30ms/step - loss: 1.7173 - accuracy: 0.5227 - val_loss: 1.7370 - val_accuracy: 0.5144
# Epoch 49/50
# 108/108 [==============================] - 3s 31ms/step - loss: 1.7082 - accuracy: 0.5235 - val_loss: 1.7284 - val_accuracy: 0.5169
# Epoch 50/50
# 108/108 [==============================] - 3s 32ms/step - loss: 1.6991 - accuracy: 0.5263 - val_loss: 1.7203 - val_accuracy: 0.5188

# %%
vgg_model_frozen.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 43)                22059
# =================================================================
# Total params: 20,046,443
# Trainable params: 22,059
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,5.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
def test_acc():
    test = pd.read_csv(data_dir + '/Test.csv')
    labels = test["ClassId"].values
    imgs = test["Path"].values
    data =[]
    for img in imgs:
        try:
            image = cv2.imread(data_dir + '/' +img)
            image_fromarray = Image.fromarray(image,'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            data.append(np.array(resize_image))
        except:
            print("Error in " + img)
            
    X_test = np.array(data)

    X_test = X_test/255
    
    return X_test, labels

# %%
X_test, labels = test_acc()

# predict
pred_x = vgg_model_frozen.predict(X_test)
pred=np.argmax(pred_x,axis=1)
    #Accuracy with the test data
final_acc = accuracy_score(labels, pred)*100
print(final_acc)
# Out:
# 42.280285035629454

# %%
# Get pretrained model

pretrained_model= tf.keras.applications.VGG19(include_top=False,
                   input_shape=(32,32,3),
                   #pooling='avg',
                   weights='imagenet')

vgg_model_top2_unfrozen = Sequential()
pretrained_model.trainable = True
for layer in pretrained_model.layers[:20]:
    layer.trainable = False
    
        
#for layer in pretrained_model.layers[:-1]: # go through until last layer
    #resnet_model.add(layer)
    

#resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
vgg_model_top2_unfrozen.add(pretrained_model)
#resnet_model.add(tf.keras.layers.BatchNormalization())
vgg_model_top2_unfrozen.add(Flatten())

prediction_layer = tf.keras.layers.Dense(43, activation='softmax')
vgg_model_top2_unfrozen.add(prediction_layer)

#model.compile(optimizer='adam', loss='categorical_crossentropy')
for i, layer in enumerate(pretrained_model.layers):
        print(i, layer.name, "-", layer.trainable)
# Out:
# 0 input_13 - False
# 1 block1_conv1 - False
# 2 block1_conv2 - False
# 3 block1_pool - False
# 4 block2_conv1 - False
# 5 block2_conv2 - False
# 6 block2_pool - False
# 7 block3_conv1 - False
# 8 block3_conv2 - False
# 9 block3_conv3 - False
# 10 block3_conv4 - False
# 11 block3_pool - False
# 12 block4_conv1 - False
# 13 block4_conv2 - False
# 14 block4_conv3 - False
# 15 block4_conv4 - False
# 16 block4_pool - False
# 17 block5_conv1 - False
# 18 block5_conv2 - False
# 19 block5_conv3 - False
# 20 block5_conv4 - True
# 21 block5_pool - True

# %%
lr = 0.0001
epochs = 50
#opt = Adam(learning_rate=lr, decay=lr / (epochs * 0.5))
opt = Adam(learning_rate=lr)

# %%
# Compile model
vgg_model_top2_unfrozen.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
len(vgg_model_top2_unfrozen.trainable_variables)
# Out:
# 4

# %%
history = vgg_model_top2_unfrozen.fit(X_train, y_train,
batch_size=256, epochs=epochs, validation_data=(X_val,
y_val))
# Out:
# Epoch 1/50
# 108/108 [==============================] - 5s 38ms/step - loss: 2.3608 - accuracy: 0.3623 - val_loss: 1.7876 - val_accuracy: 0.4882
# Epoch 2/50
# 108/108 [==============================] - 3s 32ms/step - loss: 1.5976 - accuracy: 0.5504 - val_loss: 1.4514 - val_accuracy: 0.5850
# Epoch 3/50
# 108/108 [==============================] - 4s 33ms/step - loss: 1.3429 - accuracy: 0.6257 - val_loss: 1.2769 - val_accuracy: 0.6420
# Epoch 4/50
# 108/108 [==============================] - 4s 33ms/step - loss: 1.1849 - accuracy: 0.6707 - val_loss: 1.1655 - val_accuracy: 0.6757
# Epoch 5/50
# 108/108 [==============================] - 3s 32ms/step - loss: 1.0739 - accuracy: 0.7020 - val_loss: 1.0636 - val_accuracy: 0.6985
# Epoch 6/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.9859 - accuracy: 0.7272 - val_loss: 1.0020 - val_accuracy: 0.7187
# Epoch 7/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.9169 - accuracy: 0.7474 - val_loss: 0.9394 - val_accuracy: 0.7351
# Epoch 8/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.8557 - accuracy: 0.7644 - val_loss: 0.8892 - val_accuracy: 0.7495
# Epoch 9/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.7997 - accuracy: 0.7842 - val_loss: 0.8353 - val_accuracy: 0.7689
# Epoch 10/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.7586 - accuracy: 0.7963 - val_loss: 0.7987 - val_accuracy: 0.7802
# Epoch 11/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.7166 - accuracy: 0.8087 - val_loss: 0.7836 - val_accuracy: 0.7734
# Epoch 12/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.6815 - accuracy: 0.8199 - val_loss: 0.7358 - val_accuracy: 0.7969
# Epoch 13/50
# 108/108 [==============================] - 4s 34ms/step - loss: 0.6480 - accuracy: 0.8303 - val_loss: 0.7107 - val_accuracy: 0.8072
# Epoch 14/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.6192 - accuracy: 0.8382 - val_loss: 0.6913 - val_accuracy: 0.8042
# Epoch 15/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.5943 - accuracy: 0.8439 - val_loss: 0.6618 - val_accuracy: 0.8201
# Epoch 16/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.5652 - accuracy: 0.8555 - val_loss: 0.6360 - val_accuracy: 0.8237
# Epoch 17/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.5457 - accuracy: 0.8571 - val_loss: 0.6288 - val_accuracy: 0.8216
# Epoch 18/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.5211 - accuracy: 0.8688 - val_loss: 0.5963 - val_accuracy: 0.8356
# Epoch 19/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.5029 - accuracy: 0.8702 - val_loss: 0.5878 - val_accuracy: 0.8297
# Epoch 20/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.4847 - accuracy: 0.8774 - val_loss: 0.5630 - val_accuracy: 0.8474
# Epoch 21/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.4679 - accuracy: 0.8811 - val_loss: 0.5522 - val_accuracy: 0.8488
# Epoch 22/50
# 108/108 [==============================] - 4s 34ms/step - loss: 0.4488 - accuracy: 0.8895 - val_loss: 0.5401 - val_accuracy: 0.8545
# Epoch 23/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.4333 - accuracy: 0.8926 - val_loss: 0.5239 - val_accuracy: 0.8550
# Epoch 24/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.4194 - accuracy: 0.8950 - val_loss: 0.5119 - val_accuracy: 0.8594
# Epoch 25/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.4077 - accuracy: 0.8998 - val_loss: 0.5016 - val_accuracy: 0.8636
# Epoch 26/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.3926 - accuracy: 0.9038 - val_loss: 0.4883 - val_accuracy: 0.8681
# Epoch 27/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.3788 - accuracy: 0.9080 - val_loss: 0.4773 - val_accuracy: 0.8692
# Epoch 28/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.3680 - accuracy: 0.9099 - val_loss: 0.4698 - val_accuracy: 0.8692
# Epoch 29/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.3551 - accuracy: 0.9157 - val_loss: 0.4686 - val_accuracy: 0.8672
# Epoch 30/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.3443 - accuracy: 0.9181 - val_loss: 0.4449 - val_accuracy: 0.8783
# Epoch 31/50
# 108/108 [==============================] - 4s 35ms/step - loss: 0.3315 - accuracy: 0.9238 - val_loss: 0.4455 - val_accuracy: 0.8770
# Epoch 32/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.3260 - accuracy: 0.9220 - val_loss: 0.4328 - val_accuracy: 0.8783
# Epoch 33/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.3132 - accuracy: 0.9267 - val_loss: 0.4215 - val_accuracy: 0.8861
# Epoch 34/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.3033 - accuracy: 0.9306 - val_loss: 0.4165 - val_accuracy: 0.8863
# Epoch 35/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.2959 - accuracy: 0.9324 - val_loss: 0.4101 - val_accuracy: 0.8854
# Epoch 36/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.2882 - accuracy: 0.9334 - val_loss: 0.4086 - val_accuracy: 0.8889
# Epoch 37/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.2803 - accuracy: 0.9339 - val_loss: 0.3910 - val_accuracy: 0.8913
# Epoch 38/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.2728 - accuracy: 0.9366 - val_loss: 0.3929 - val_accuracy: 0.8873
# Epoch 39/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.2646 - accuracy: 0.9394 - val_loss: 0.3928 - val_accuracy: 0.8866
# Epoch 40/50
# 108/108 [==============================] - 4s 34ms/step - loss: 0.2588 - accuracy: 0.9414 - val_loss: 0.3803 - val_accuracy: 0.8958
# Epoch 41/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.2551 - accuracy: 0.9410 - val_loss: 0.3727 - val_accuracy: 0.8951
# Epoch 42/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.2473 - accuracy: 0.9433 - val_loss: 0.3633 - val_accuracy: 0.9034
# Epoch 43/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.2387 - accuracy: 0.9472 - val_loss: 0.3567 - val_accuracy: 0.9013
# Epoch 44/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.2331 - accuracy: 0.9494 - val_loss: 0.3582 - val_accuracy: 0.9018
# Epoch 45/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.2276 - accuracy: 0.9504 - val_loss: 0.3473 - val_accuracy: 0.9037
# Epoch 46/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.2240 - accuracy: 0.9499 - val_loss: 0.3451 - val_accuracy: 0.9087
# Epoch 47/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.2151 - accuracy: 0.9537 - val_loss: 0.3434 - val_accuracy: 0.9035
# Epoch 48/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.2095 - accuracy: 0.9541 - val_loss: 0.3378 - val_accuracy: 0.9056
# Epoch 49/50
# 108/108 [==============================] - 4s 35ms/step - loss: 0.2058 - accuracy: 0.9554 - val_loss: 0.3442 - val_accuracy: 0.9003
# Epoch 50/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.2000 - accuracy: 0.9563 - val_loss: 0.3249 - val_accuracy: 0.9136

# %%
resnet_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 43)                22059
# =================================================================
# Total params: 20,046,443
# Trainable params: 2,381,867
# Non-trainable params: 17,664,576
# _________________________________________________________________

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
def test_acc():
    test = pd.read_csv(data_dir + '/Test.csv')
    labels = test["ClassId"].values
    imgs = test["Path"].values
    data =[]
    for img in imgs:
        try:
            image = cv2.imread(data_dir + '/' +img)
            image_fromarray = Image.fromarray(image,'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            data.append(np.array(resize_image))
        except:
            print("Error in " + img)
            
    X_test = np.array(data)

    X_test = X_test/255
    
    return X_test, labels

# %%
X_test, labels = test_acc()

# predict
pred_x = vgg_model_top2_unfrozen.predict(X_test)
pred=np.argmax(pred_x,axis=1)
    #Accuracy with the test data
final_acc = accuracy_score(labels, pred)*100
print(final_acc)
# Out:
# 58.6935866983373

# %%
# Get pretrained model

pretrained_model= tf.keras.applications.VGG19(include_top=False,
                   input_shape=(32,32,3),
                   #pooling='avg',
                   weights='imagenet')

vgg_model_unfreeze_1block = Sequential()
pretrained_model.trainable = True
for layer in pretrained_model.layers[:17]:
    layer.trainable = False
    
        
#for layer in pretrained_model.layers[:-1]: # go through until last layer
    #resnet_model.add(layer)
    

#resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
vgg_model_unfreeze_1block.add(pretrained_model)
#resnet_model.add(tf.keras.layers.BatchNormalization())
vgg_model_unfreeze_1block.add(Flatten())

prediction_layer = tf.keras.layers.Dense(43, activation='softmax')
vgg_model_unfreeze_1block.add(prediction_layer)

#model.compile(optimizer='adam', loss='categorical_crossentropy')
for i, layer in enumerate(pretrained_model.layers):
        print(i, layer.name, "-", layer.trainable)
# Out:
# 0 input_15 - False
# 1 block1_conv1 - False
# 2 block1_conv2 - False
# 3 block1_pool - False
# 4 block2_conv1 - False
# 5 block2_conv2 - False
# 6 block2_pool - False
# 7 block3_conv1 - False
# 8 block3_conv2 - False
# 9 block3_conv3 - False
# 10 block3_conv4 - False
# 11 block3_pool - False
# 12 block4_conv1 - False
# 13 block4_conv2 - False
# 14 block4_conv3 - False
# 15 block4_conv4 - False
# 16 block4_pool - False
# 17 block5_conv1 - True
# 18 block5_conv2 - True
# 19 block5_conv3 - True
# 20 block5_conv4 - True
# 21 block5_pool - True

# %%
lr = 0.0001
epochs = 15
#opt = Adam(learning_rate=lr, decay=lr / (epochs * 0.5))
opt = Adam(learning_rate=lr)

# %%
# Compile model
vgg_model_unfreeze_1block.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
len(vgg_model_unfreeze_1block.trainable_variables)
# Out:
# 10

# %%
history = vgg_model_unfreeze_1block.fit(X_train, y_train,
batch_size=256, epochs=epochs, validation_data=(X_val,
y_val))
# Out:
# Epoch 1/15
# 108/108 [==============================] - 6s 47ms/step - loss: 1.6108 - accuracy: 0.5222 - val_loss: 0.9463 - val_accuracy: 0.6785
# Epoch 2/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.6734 - accuracy: 0.7792 - val_loss: 0.5136 - val_accuracy: 0.8357
# Epoch 3/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.3932 - accuracy: 0.8746 - val_loss: 0.3586 - val_accuracy: 0.8883
# Epoch 4/15
# 108/108 [==============================] - 4s 41ms/step - loss: 0.2600 - accuracy: 0.9173 - val_loss: 0.3182 - val_accuracy: 0.8988
# Epoch 5/15
# 108/108 [==============================] - 4s 41ms/step - loss: 0.1905 - accuracy: 0.9408 - val_loss: 0.2703 - val_accuracy: 0.9096
# Epoch 6/15
# 108/108 [==============================] - 4s 41ms/step - loss: 0.1387 - accuracy: 0.9578 - val_loss: 0.2789 - val_accuracy: 0.9117
# Epoch 7/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.1091 - accuracy: 0.9671 - val_loss: 0.1697 - val_accuracy: 0.9468
# Epoch 8/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.0912 - accuracy: 0.9715 - val_loss: 0.1759 - val_accuracy: 0.9447
# Epoch 9/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.0709 - accuracy: 0.9777 - val_loss: 0.1386 - val_accuracy: 0.9580
# Epoch 10/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.0646 - accuracy: 0.9799 - val_loss: 0.1619 - val_accuracy: 0.9504
# Epoch 11/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.0515 - accuracy: 0.9843 - val_loss: 0.1458 - val_accuracy: 0.9549
# Epoch 12/15
# 108/108 [==============================] - 4s 41ms/step - loss: 0.0449 - accuracy: 0.9861 - val_loss: 0.1788 - val_accuracy: 0.9460
# Epoch 13/15
# 108/108 [==============================] - 4s 41ms/step - loss: 0.0455 - accuracy: 0.9867 - val_loss: 0.1625 - val_accuracy: 0.9504
# Epoch 14/15
# 108/108 [==============================] - 4s 41ms/step - loss: 0.0480 - accuracy: 0.9860 - val_loss: 0.1274 - val_accuracy: 0.9638
# Epoch 15/15
# 108/108 [==============================] - 4s 40ms/step - loss: 0.0343 - accuracy: 0.9897 - val_loss: 0.1190 - val_accuracy: 0.9664

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
X_test, labels = test_acc()

# predict
pred_x = vgg_model_unfreeze_1block.predict(X_test)
pred=np.argmax(pred_x,axis=1)
    #Accuracy with the test data
final_acc = accuracy_score(labels, pred)*100
print(final_acc)
# Out:
# 70.90261282660333

# %%
# Get pretrained model

pretrained_model= tf.keras.applications.VGG19(include_top=False,
                   input_shape=(32,32,3),
                   #pooling='avg',
                   weights='imagenet')

vgg_model_unfreeze_2block = Sequential()
pretrained_model.trainable = True
for layer in pretrained_model.layers[:12]:
    layer.trainable = False
    
        
#for layer in pretrained_model.layers[:-1]: # go through until last layer
    #resnet_model.add(layer)
    

#resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
vgg_model_unfreeze_2block.add(pretrained_model)
#resnet_model.add(tf.keras.layers.BatchNormalization())
vgg_model_unfreeze_2block.add(Flatten())

prediction_layer = tf.keras.layers.Dense(43, activation='softmax')
vgg_model_unfreeze_2block.add(prediction_layer)

#model.compile(optimizer='adam', loss='categorical_crossentropy')
for i, layer in enumerate(pretrained_model.layers):
        print(i, layer.name, "-", layer.trainable)
# Out:
# 0 input_16 - False
# 1 block1_conv1 - False
# 2 block1_conv2 - False
# 3 block1_pool - False
# 4 block2_conv1 - False
# 5 block2_conv2 - False
# 6 block2_pool - False
# 7 block3_conv1 - False
# 8 block3_conv2 - False
# 9 block3_conv3 - False
# 10 block3_conv4 - False
# 11 block3_pool - False
# 12 block4_conv1 - True
# 13 block4_conv2 - True
# 14 block4_conv3 - True
# 15 block4_conv4 - True
# 16 block4_pool - True
# 17 block5_conv1 - True
# 18 block5_conv2 - True
# 19 block5_conv3 - True
# 20 block5_conv4 - True
# 21 block5_pool - True

# %%
lr = 0.0001
epochs = 15
#opt = Adam(learning_rate=lr, decay=lr / (epochs * 0.5))
opt = Adam(learning_rate=lr)

# %%
# Compile model
vgg_model_unfreeze_2block.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
len(vgg_model_unfreeze_2block.trainable_variables)
# Out:
# 18

# %%
history = vgg_model_unfreeze_2block.fit(X_train, y_train,
batch_size=256, epochs=epochs, validation_data=(X_val,
y_val))
# Out:
# Epoch 1/15
# 108/108 [==============================] - 7s 57ms/step - loss: 1.3930 - accuracy: 0.5742 - val_loss: 0.7842 - val_accuracy: 0.7337
# Epoch 2/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.4990 - accuracy: 0.8300 - val_loss: 0.3227 - val_accuracy: 0.8959
# Epoch 3/15
# 108/108 [==============================] - 6s 51ms/step - loss: 0.2527 - accuracy: 0.9132 - val_loss: 0.2092 - val_accuracy: 0.9349
# Epoch 4/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.1855 - accuracy: 0.9389 - val_loss: 0.1835 - val_accuracy: 0.9414
# Epoch 5/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.1070 - accuracy: 0.9643 - val_loss: 0.1225 - val_accuracy: 0.9604
# Epoch 6/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.0744 - accuracy: 0.9756 - val_loss: 0.0805 - val_accuracy: 0.9756
# Epoch 7/15
# 108/108 [==============================] - 6s 51ms/step - loss: 0.0503 - accuracy: 0.9835 - val_loss: 0.1122 - val_accuracy: 0.9625
# Epoch 8/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.0567 - accuracy: 0.9812 - val_loss: 0.1446 - val_accuracy: 0.9532
# Epoch 9/15
# 108/108 [==============================] - 6s 51ms/step - loss: 0.0532 - accuracy: 0.9820 - val_loss: 0.0993 - val_accuracy: 0.9700
# Epoch 10/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.0509 - accuracy: 0.9835 - val_loss: 0.1044 - val_accuracy: 0.9648
# Epoch 11/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.0433 - accuracy: 0.9852 - val_loss: 0.0718 - val_accuracy: 0.9782
# Epoch 12/15
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0326 - accuracy: 0.9904 - val_loss: 0.0782 - val_accuracy: 0.9747
# Epoch 13/15
# 108/108 [==============================] - 6s 51ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.0779 - val_accuracy: 0.9770
# Epoch 14/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.0701 - val_accuracy: 0.9793
# Epoch 15/15
# 108/108 [==============================] - 6s 52ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0612 - val_accuracy: 0.9825

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
X_test, labels = test_acc()

# predict
pred_x = vgg_model_unfreeze_2block.predict(X_test)
pred=np.argmax(pred_x,axis=1)
    #Accuracy with the test data
final_acc = accuracy_score(labels, pred)*100
print(final_acc)
# Out:
# 80.1741884402217

# %%
# Check batch of images


#image_batch, label_batch = next(iter(X_train))
#feature_batch = pretrained_model(image_batch)
#print(feature_batch.shape)

# %%
# Check all blocks
for i, layer in enumerate(pretrained_model.layers):
        print(i, layer.name, "-", layer.trainable)
# Out:
# 0 input_14 - False
# 1 block1_conv1 - False
# 2 block1_conv2 - False
# 3 block1_pool - False
# 4 block2_conv1 - False
# 5 block2_conv2 - False
# 6 block2_pool - False
# 7 block3_conv1 - False
# 8 block3_conv2 - False
# 9 block3_conv3 - False
# 10 block3_conv4 - False
# 11 block3_pool - False
# 12 block4_conv1 - False
# 13 block4_conv2 - False
# 14 block4_conv3 - False
# 15 block4_conv4 - False
# 16 block4_pool - False
# 17 block5_conv1 - True
# 18 block5_conv2 - True
# 19 block5_conv3 - True
# 20 block5_conv4 - True
# 21 block5_pool - True

# %%
#pretrained_model.summary()

# %%
# Add classificaiton head 

# Add global avarage pooling (instead of Flatten())
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
#feature_batch_average = global_average_layer(feature_batch)
#print(feature_batch_average.shape)

# Add Dense layers
dense_layer256 = tf.keras.layers.Dense(256, activation='relu')
dense_layer512 = tf.keras.layers.Dense(512, activation='relu')
dense_layer1028 = tf.keras.layers.Dense(1028, activation='relu')
prediction_layer = tf.keras.layers.Dense(43, activation='softmax')
#prediction_batch = prediction_layer(feature_batch_average)
#print(prediction_batch.shape)

# %%
# Build model
#inputs = tf.keras.Input(shape=(32, 32, 3))
#pretrained_model = pretrained_model(inputs, training=False)
pretrained_model = pretrained_model[:-2]
resnet_model = Sequential()
#resnet_model.add(tf.keras.Input(shape=(32,32,3)))
resnet_model.add(pretrained_model)
resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
resnet_model.add(Flatten())
#resnet_model.add(tf.keras.layers.Dropout(0.2))
resnet_model.add(dense_layer512)
#resnet_model.add(tf.keras.layers.Dropout(0.5))
resnet_model.add(dense_layer256)
resnet_model.add(tf.keras.layers.Dropout(0.5))
#resnet_model.add(tf.keras.layers.Dropout(0.5))
prediction_layer = tf.keras.layers.Dense(43, activation='softmax')
resnet_model.add(prediction_layer)
#model = tf.keras.Model(inputs, outputs)

# %%
resnet_model = tf.keras.Sequential([
        pretrained_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(43, activation='softmax')
    ])

# %%
'''
for i, layer in enumerate(pretrained_model.layers):
        print(i, layer.name, "-", layer.trainable)
        
print('final model')
for i, layer in enumerate(resnet_model.layers):
        print(i, layer.name, "-", layer.trainable)
        '''

# %%
lr = 0.0001
epochs = 10
opt = Adam(learning_rate=lr, decay=lr / (epochs * 0.5))

# %%
'''
aug = ImageDataGenerator(
 rotation_range=10,
 zoom_range=0.15,
 width_shift_range=0.1,
 height_shift_range=0.1,
 shear_range=0.15,
 horizontal_flip=False,
 vertical_flip=False,
 fill_mode="nearest"
 )
'''

# %%
# Compile model
resnet_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
resnet_model.summary()

# %%
history = resnet_model.fit(X_train, y_train,
batch_size=256, epochs=epochs, validation_data=(X_val,
y_val))

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
def test_acc():
    test = pd.read_csv(data_dir + '/Test.csv')
    labels = test["ClassId"].values
    imgs = test["Path"].values
    data =[]
    for img in imgs:
        try:
            image = cv2.imread(data_dir + '/' +img)
            image_fromarray = Image.fromarray(image,'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            data.append(np.array(resize_image))
        except:
            print("Error in " + img)
            
    X_test = np.array(data)

    X_test = X_test/255
    
    return X_test, labels

# %%
X_test, labels = test_acc()

# predict
pred_x = resnet_model.predict(X_test)
pred=np.argmax(pred_x,axis=1)
    #Accuracy with the test data
final_acc = accuracy_score(labels, pred)*100
print(final_acc)
