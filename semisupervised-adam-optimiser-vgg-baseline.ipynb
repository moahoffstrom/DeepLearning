# %% [markdown]
# # DON'T EDIT THIS NOTEBOOK
# ## DOWNLOAD IT AND THEN IMPORT to A NEW ONE

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score 
import os
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Flatten,Dense

# %%
data_dir = '../input/gtsrb-german-traffic-sign'
train_path = '../input/gtsrb-german-traffic-sign/Train'
test_path = '../input/gtsrb-german-traffic-sign/Test'

# %%
IMG_HEIGHT = 32
IMG_WIDTH = 32
NUM_CATEGORIES = len(os.listdir(train_path))

# %%
print(NUM_CATEGORIES)

# %%
classes = { 0:'Speed limit (20km/h)',
 1:'Speed limit (30km/h)',
 2:'Speed limit (50km/h)',
 3:'Speed limit (60km/h)',
 4:'Speed limit (70km/h)',
 5:'Speed limit (80km/h)',
 6:'End of speed limit (80km/h)',
 7:'Speed limit (100km/h)',
 8:'Speed limit (120km/h)',
 9:'No passing',
 10:'No passing veh over 3.5 tons',
 11:'Right-of-way at intersection',
 12:'Priority road',
 13:'Yield',
 14:'Stop',
 15:'No vehicles',
 16:'Veh > 3.5 tons prohibited',
 17:'No entry',
 18:'General caution',
 19:'Dangerous curve left',
 20:'Dangerous curve right',
 21:'Double curve',
 22:'Bumpy road',
 23:'Slippery road',
 24:'Road narrows on the right',
 25:'Road work',
 26:'Traffic signals',
 27:'Pedestrians',
 28:'Children crossing',
 29:'Bicycles crossing',
 30:'Beware of ice/snow',
 31:'Wild animals crossing',
 32:'End speed + passing limits',
 33:'Turn right ahead',
 34:'Turn left ahead',
 35:'Ahead only',
 36:'Go straight or right',
 37:'Go straight or left',
 38:'Keep right',
 39:'Keep left',
 40:'Roundabout mandatory',
 41:'End of no passing',
 42:'End no passing veh > 3.5 tons' }

# %%
image_data = []
image_labels = []

# %%
for i in range(NUM_CATEGORIES):
    path = data_dir + '/Train/' + str(i)
    images = os.listdir(path)
    for img in images:
        image = cv2.imread(path + '/' + img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        image_data.append(np.array(resize_image))
        image_labels.append(i)
# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)
print(image_data.shape, image_labels.shape)

# %%
shuffle_indexes = np.arange(image_data.shape[0])
np.random.shuffle(shuffle_indexes)
image_data = image_data[shuffle_indexes]
image_labels = image_labels[shuffle_indexes]

# %%
X_train,y_train=(image_data, image_labels)

# %%
X_train = X_train/255

# %%
print("X_train", X_train.shape)
print("X_valid", X_val.shape)
print("y_train", y_train.shape)
print("y_valid", y_val.shape)

# %%
y_train = keras.utils.to_categorical(y_train,NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)

# %%
print(y_train.shape)
print(X_train.shape)

# %%
len(data_0)

# %%
data_0 = [ x for x,y in zip(X_train,y_train) if y == 0 ] 
data_1 = [ x for x,y in zip(X_train,y_train) if y == 1 ] 
data_2 = [ x for x,y in zip(X_train,y_train) if y == 2 ] 
data_3 = [ x for x,y in zip(X_train,y_train) if y == 3 ] 
data_4 = [ x for x,y in zip(X_train,y_train) if y == 4 ] 
data_5 = [ x for x,y in zip(X_train,y_train) if y == 5 ] 
data_6 = [ x for x,y in zip(X_train,y_train) if y == 6 ] 
data_7 = [ x for x,y in zip(X_train,y_train) if y == 7 ] 
data_8 = [ x for x,y in zip(X_train,y_train) if y == 8 ] 
data_9 = [ x for x,y in zip(X_train,y_train) if y == 9 ] 
data_10 = [ x for x,y in zip(X_train,y_train) if y == 10 ] 
data_11 = [ x for x,y in zip(X_train,y_train) if y == 11 ] 
data_12 = [ x for x,y in zip(X_train,y_train) if y == 12 ] 
data_13 = [ x for x,y in zip(X_train,y_train) if y == 13 ] 
data_14 = [ x for x,y in zip(X_train,y_train) if y == 14 ] 
data_15 = [ x for x,y in zip(X_train,y_train) if y == 15 ] 
data_16 = [ x for x,y in zip(X_train,y_train) if y == 16 ] 
data_17 = [ x for x,y in zip(X_train,y_train) if y == 17 ] 
data_18 = [ x for x,y in zip(X_train,y_train) if y == 18 ] 
data_19 = [ x for x,y in zip(X_train,y_train) if y == 19 ] 
data_20 = [ x for x,y in zip(X_train,y_train) if y == 20 ] 
data_21 = [ x for x,y in zip(X_train,y_train) if y == 21 ] 
data_22= [ x for x,y in zip(X_train,y_train) if y == 22 ] 
data_23 = [ x for x,y in zip(X_train,y_train) if y == 23 ] 
data_24 = [ x for x,y in zip(X_train,y_train) if y == 24 ] 
data_25 = [ x for x,y in zip(X_train,y_train) if y == 25 ] 
data_26 = [ x for x,y in zip(X_train,y_train) if y == 26 ] 
data_27 = [ x for x,y in zip(X_train,y_train) if y == 27 ] 
data_28 = [ x for x,y in zip(X_train,y_train) if y == 28 ] 
data_29 = [ x for x,y in zip(X_train,y_train) if y == 29 ] 
data_30 = [ x for x,y in zip(X_train,y_train) if y == 30 ] 
data_31 = [ x for x,y in zip(X_train,y_train) if y == 31]
data_32 = [ x for x,y in zip(X_train,y_train) if y == 32 ]
data_33 = [ x for x,y in zip(X_train,y_train) if y == 33]
data_34 = [ x for x,y in zip(X_train,y_train) if y == 34 ]
data_35 = [ x for x,y in zip(X_train,y_train) if y == 35 ]
data_36 = [ x for x,y in zip(X_train,y_train) if y == 36 ]
data_37 = [ x for x,y in zip(X_train,y_train) if y == 37 ]
data_38 = [ x for x,y in zip(X_train,y_train) if y == 38 ]
data_39 = [ x for x,y in zip(X_train,y_train) if y == 39 ]
data_40 = [ x for x,y in zip(X_train,y_train) if y == 40 ]
data_41 = [ x for x,y in zip(X_train,y_train) if y == 41 ]
data_42 = [ x for x,y in zip(X_train,y_train) if y == 42 ]

# %%
source = 0
target = 20

# %%
x_train_shorten =  data_0[source:target] + data_1[source:target] + data_2[source:target] + data_3[source:target] + data_4[source:target] + data_5[source:target] + data_6[source:target] + data_7[source:target] + data_8[source:target] + data_9[source:target]+data_10[source:target]+data_11[source:target]+data_12[source:target]+data_13[source:target]+data_14[source:target]+data_15[source:target]+data_16[source:target]+data_17[source:target]+data_18[source:target]+data_19[source:target]+data_20[source:target]+ data_21[source:target]+data_22[source:target]+data_23[source:target]+data_24[source:target]+data_25[source:target]+data_26[source:target]+data_27[source:target]+data_28[source:target]+data_29[source:target]+data_30[source:target]+data_31[source:target]+data_32[source:target]+data_33[source:target]+data_34[source:target]+data_35[source:target]+data_36[source:target]+data_37[source:target]+data_38[source:target]+data_39[source:target]+data_40[source:target]+data_41[source:target]+data_42[source:target]

# %%
y_train_shorten = list(np.zeros(target)) + list(np.ones(target)) + list( np.ones(target) * 2 ) + list( np.ones(target) * 3 ) + list( np.ones(target) * 4 ) + list( np.ones(target) * 5 ) + list( np.ones(target) * 6 ) + list( np.ones(target) * 7 ) + list( np.ones(target) * 8 ) + list( np.ones(target) * 9 ) + list( np.ones(target) * 10 ) + list( np.ones(target) * 11 ) + list( np.ones(target) * 12 ) + list( np.ones(target) * 13 ) + list( np.ones(target) * 14 ) + list( np.ones(target) * 15 ) + list( np.ones(target) * 16 ) + list( np.ones(target) * 17 ) + list( np.ones(target) * 18 )+ list( np.ones(target) * 19 )+ list( np.ones(target) * 20 ) + list( np.ones(target) * 21 )+ list( np.ones(target) * 22 )+ list( np.ones(target) * 23 )+ list( np.ones(target) * 24 )+ list( np.ones(target) * 25 )+ list( np.ones(target) * 26 )+ list( np.ones(target) * 27 )+ list( np.ones(target) * 28 )+ list( np.ones(target) * 29 )+ list( np.ones(target) * 30 )+ list( np.ones(target) * 31 )+ list( np.ones(target) * 32 )+ list( np.ones(target) * 33 )+ list( np.ones(target) * 34 )+list( np.ones(target) * 35 )+ list( np.ones(target) * 36 )+ list( np.ones(target) * 37 )+ list( np.ones(target) * 38 )+ list( np.ones(target) * 39 )+ list( np.ones(target) * 40 )+ list( np.ones(target) * 41 )+ list( np.ones(target) * 42 )

# %%
x_train_shorten = np.array( x_train_shorten )
y_train_shorten = np.array( y_train_shorten )

# %%
x_train_shorten.shape

# %%
y_train_shorten.shape

# %%
source = 20
target = 190

# %%
x_train_unlabelled = data_0[source:target] + data_1[source:target] + data_2[source:target] + data_3[source:target] + data_4[source:target] + data_5[source:target] + data_6[source:target] + data_7[source:target] + data_8[source:target] + data_9[source:target]+data_10[source:target]+data_11[source:target]+data_12[source:target]+data_13[source:target]+data_14[source:target]+data_15[source:target]+data_16[source:target]+data_17[source:target]+data_18[source:target]+data_19[source:target]+data_20[source:target]+ data_21[source:target]+data_22[source:target]+data_23[source:target]+data_24[source:target]+data_25[source:target]+data_26[source:target]+data_27[source:target]+data_28[source:target]+data_29[source:target]+data_30[source:target]+data_31[source:target]+data_32[source:target]+data_33[source:target]+data_34[source:target]+data_35[source:target]+data_36[source:target]+data_37[source:target]+data_38[source:target]+data_39[source:target]+data_40[source:target]+data_41[source:target]+data_42[source:target]

# %%
y_train_unlabelled = list(np.zeros(target - source)) + list(np.ones(target - source)) + list( np.ones(target - source) * 2 ) + list( np.ones(target - source) * 3 ) + list( np.ones(target - source) * 4 ) + list( np.ones(target - source) * 5 ) + list( np.ones(target - source) * 6 ) + list( np.ones(target - source) * 7 ) + list( np.ones(target - source) * 8 ) + list( np.ones(target - source) * 9 )+ list( np.ones(target - source) * 10 )+ list( np.ones(target - source) * 11 )+ list( np.ones(target - source) * 12 )+ list( np.ones(target - source) * 13 )+ list( np.ones(target - source) * 14 )+ list( np.ones(target - source) * 15 )+ list( np.ones(target - source) * 16 )+ list( np.ones(target - source) * 17 )+ list( np.ones(target - source) * 18 )+ list( np.ones(target - source) * 19 )+ list( np.ones(target - source) * 20 )+ list( np.ones(target - source) * 21 )+ list( np.ones(target - source) * 22 )+ list( np.ones(target - source) * 23 )+ list( np.ones(target - source) * 24 )+ list( np.ones(target - source) * 25 )+ list( np.ones(target - source) * 26 )+ list( np.ones(target - source) * 27 )+ list( np.ones(target - source) * 28 )+ list( np.ones(target - source) * 29 )+ list( np.ones(target - source) * 30 )+ list( np.ones(target - source) * 31 )+ list( np.ones(target - source) * 32 )+ list( np.ones(target - source) * 33 )+ list( np.ones(target - source) * 34 )+ list( np.ones(target - source) * 35 )+ list( np.ones(target - source) * 36 )+ list( np.ones(target - source) * 37 )+ list( np.ones(target - source) * 38 )+ list( np.ones(target - source) * 39 )+ list( np.ones(target - source) * 40 )+ list( np.ones(target - source) * 41 )+ list( np.ones(target - source) * 42 )

# %%
x_train_unlabelled = np.array( x_train_unlabelled )
y_train_unlabelled = np.array( y_train_unlabelled )

# %%
x_train_unlabelled.shape

# %%
y_train_unlabelled.shape

# %%
source = 190
target = 210

# %%
x_eval_shorten = data_0[source:target] + data_1[source:target] + data_2[source:target] + data_3[source:target] + data_4[source:target] + data_5[source:target] + data_6[source:target] + data_7[source:target] + data_8[source:target] + data_9[source:target]+ data_10[source:target]+data_11[source:target]+data_12[source:target]+data_13[source:target]+data_14[source:target]+data_15[source:target]+data_16[source:target]+data_17[source:target]+data_18[source:target]+data_19[source:target]+data_20[source:target]+ data_21[source:target]+data_22[source:target]+data_23[source:target]+data_24[source:target]+data_25[source:target]+data_26[source:target]+data_27[source:target]+data_28[source:target]+data_29[source:target]+data_30[source:target]+data_31[source:target]+data_32[source:target]+data_33[source:target]+data_34[source:target]+data_35[source:target]+data_36[source:target]+data_37[source:target]+data_38[source:target]+data_39[source:target]+data_40[source:target]+data_41[source:target]+data_42[source:target]

# %%
y_eval_shorten = list(np.zeros(target - source)) + list(np.ones(target - source)) + list( np.ones(target - source) * 2 ) + list( np.ones(target - source) * 3 ) + list( np.ones(target - source) * 4 ) + list( np.ones(target - source) * 5 ) + list( np.ones(target - source) * 6 ) + list( np.ones(target - source) * 7 ) + list( np.ones(target - source) * 8 ) + list( np.ones(target - source) * 9 )+ list( np.ones(target - source) * 10 )+ list( np.ones(target - source) * 11 )+ list( np.ones(target - source) * 12 )+ list( np.ones(target - source) * 13 )+ list( np.ones(target - source) * 14 )+ list( np.ones(target - source) * 15 )+ list( np.ones(target - source) * 16 )+ list( np.ones(target - source) * 17 )+ list( np.ones(target - source) * 18 )+ list( np.ones(target - source) * 19 )+ list( np.ones(target - source) * 20 )+ list( np.ones(target - source) * 21 )+ list( np.ones(target - source) * 22 )+ list( np.ones(target - source) * 23 )+ list( np.ones(target - source) * 24 )+ list( np.ones(target - source) * 25 )+ list( np.ones(target - source) * 26 )+ list( np.ones(target - source) * 27 )+ list( np.ones(target - source) * 28 )+ list( np.ones(target - source) * 29 )+ list( np.ones(target - source) * 30 )+ list( np.ones(target - source) * 31 )+ list( np.ones(target - source) * 32 )+ list( np.ones(target - source) * 33 )+ list( np.ones(target - source) * 34 )+ list( np.ones(target - source) * 35 )+ list( np.ones(target - source) * 36 )+ list( np.ones(target - source) * 37 )+ list( np.ones(target - source) * 38 )+ list( np.ones(target - source) * 39 )+ list( np.ones(target - source) * 40 )+ list( np.ones(target - source) * 41 )+ list( np.ones(target - source) * 42 )

# %%
x_eval_shorten = np.array( x_eval_shorten )
y_eval_shorten = np.array( y_eval_shorten )

# %%
x_eval_shorten.shape

# %%
y_eval_shorten.shape

# %%
batch_size = 100

train_dataset = tf.data.Dataset.from_tensor_slices((x_train_shorten,y_train_shorten))
train_dataset = train_dataset.shuffle(1000).batch(batch_size)

pseudo_dataset = tf.data.Dataset.from_tensor_slices((x_train_unlabelled))
pseudo_dataset = pseudo_dataset.shuffle(1000).batch(batch_size)

eval_dataset = tf.data.Dataset.from_tensor_slices((x_eval_shorten,y_eval_shorten))
eval_dataset = eval_dataset.shuffle(1000).batch(batch_size)

# %%
lr=0.0003

# %%
opt = Adam(learning_rate=lr)

# %%
# Get pretrained model

pretrained_model= tf.keras.applications.VGG19(include_top=False,
                   input_shape=(32,32,3),
                   #pooling='avg',
                   weights='imagenet')

vgg_model_unfreeze_2block = Sequential()
pretrained_model.trainable = True
for layer in pretrained_model.layers[:12]:
    layer.trainable = False
    
        
#for layer in pretrained_model.layers[:-1]: # go through until last layer
    #resnet_model.add(layer)
    

#resnet_model.add(tf.keras.layers.BatchNormalization(renorm=True))
vgg_model_unfreeze_2block.add(pretrained_model)
#resnet_model.add(tf.keras.layers.BatchNormalization())
vgg_model_unfreeze_2block.add(Flatten())

prediction_layer = tf.keras.layers.Dense(43, activation='softmax')
vgg_model_unfreeze_2block.add(prediction_layer)

#model.compile(optimizer='adam', loss='categorical_crossentropy')
for i, layer in enumerate(pretrained_model.layers):
        print(i, layer.name, "-", layer.trainable)

# %%
def test_acc():
    test = pd.read_csv(data_dir + '/Test.csv')
    labels = test["ClassId"].values
    imgs = test["Path"].values
    data =[]
    for img in imgs:
        try:
            image = cv2.imread(data_dir + '/' +img)
            image_fromarray = Image.fromarray(image,'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            data.append(np.array(resize_image))
        except:
            print("Error in " + img)
            
    X_test = np.array(data)

    X_test = X_test/255
    
    return X_test, labels

# %%
vgg_model_unfreeze_2block.compile(optimizer=opt,loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
vgg_model_unfreeze_2block.fit(train_dataset, validation_data=eval_dataset, batch_size=100, epochs=100)

# %%
X_test, labels = test_acc()

# predict
pred_x = vgg_model_unfreeze_2block.predict(X_test)
pred=np.argmax(pred_x,axis=1)
    #Accuracy with the test data
final_acc = accuracy_score(labels, pred)*100
print(final_acc)

# %%
batch_size=100

# %%
avg_main_loss = tf.keras.metrics.Mean(name='avg_main_loss', dtype=tf.float32)
pseudo_steps = int(x_train_unlabelled.shape[0] / batch_size )
eval_steps = int(x_eval_shorten.shape[0] / batch_size )

epoch = 5

vgg_model_unfreeze_2block_optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

x_values = np.array([])
threshold = 0.90

for epoch_idx in range( epoch ):

  print( "Epoch {}/{}".format( epoch_idx + 1, epoch ) )
  vgg_model_unfreeze_2block.evaluate(eval_dataset)

  for _ in range(20):

    pseudo_labels = vgg_model_unfreeze_2block.predict( x_train_unlabelled ) 
    

    # only accept psuedo labels with certain threshold accuracy in their probability   
    pseudo_labels = np.array( [ np.argmax(x) if np.max(x) > threshold else -1 for x in pseudo_labels])
    dataset = np.array( [ [x,y] for x,y in zip( x_train_unlabelled, pseudo_labels ) if y != -1 ])
    x_values = np.array( [x for x,y in dataset ])
    y_values = np.array( [y for x,y in dataset ])
    
   

    pseudo_dataset = tf.data.Dataset.from_tensor_slices((x_values, y_values ))
    pseudo_dataset = pseudo_dataset.shuffle(1000).batch(batch_size)


    vgg_model_unfreeze_2block.fit(pseudo_dataset, batch_size=128, epochs=1, verbose=0)
    vgg_model_unfreeze_2block.fit(train_dataset, batch_size=128, epochs=1, verbose=0)

# %%
X_test, labels = test_acc()

# predict
pred_x = vgg_model_unfreeze_2block.predict(X_test)
pred=np.argmax(pred_x,axis=1)
    #Accuracy with the test data
final_acc = accuracy_score(labels, pred)*100
print(final_acc)
